# %%
import glob
import os
import pathlib

import numpy as np
import pandas as pd

import torch
import torchvision
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch import functional as F

from torchvision import transforms
from torchinfo import torchinfo
from tqdm import tqdm
import matplotlib.pyplot as plt

import albumentations as A
import torch.nn.functional as F

from PIL import Image

import torchmetrics
from torchvision.utils import save_image, make_grid
import cv2
# from util.io import load_ckpt

# from util.loss import  InpaintingLoss
import os, glob

import efficientunet
import random

device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device("cpu")


import wandb
# Out:
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")

# %%
# dataset_path = 'Datasets/inpainting/img_align_celeba/'

dataset_path = 'Datasets/inpainting/img_align_celeba/'

# %%
files = glob.glob(dataset_path+'*.jpg')

# %%
sizes = (192, 192)

rescale_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(sizes, antialias= False)
])

augment = transforms.Compose([
    # transforms.RandomAffine(30, scale = (0.9, 1.1), shear = 5, interpolation=transforms.InterpolationMode.NEAREST),
    transforms.RandomResizedCrop(sizes, (0.7, 1), ratio = (3/4, 4/3), antialias = None)
])
random_erase = transforms.Compose([
    transforms.RandomErasing(0.99, (0.35, 0.5), ratio = (0.3, 3), value = 0)
])

# %%
class celebDataset(Dataset):
    def __init__(self, files, erase = random_erase, augment = None):
        self.faces = files 
        self.erase = erase
        self.augment = augment


    def __len__(self):
        return len(self.faces)

    def __getitem__(self, idx):
        img = Image.open(self.faces[idx]).convert("RGB")
        img = rescale_transform(img)

        if self.augment is not None:
            img = self.augment(img)

        masked = random_erase(img)
        # mask = np.ones(sizes)
        # left_limit = max(0, sizes[0]//7 + random.randint(-30, +30))
        # right_limit = min(6*sizes[0]//7 + random.randint(-10, +30), sizes[1])
        # mask[int(3*sizes[0]//7) + random.randint(-20, +30):, left_limit: right_limit] = 0

        # masked = img*(torch.Tensor(mask[None, ...]).float())
        return img, masked

# %%
dataset = celebDataset(files, erase = random_erase, augment = augment)

train_dataset, val_dataset = torch.utils.data.random_split(dataset, [0.9, 0.1])

# %%
plt.imshow(train_dataset[0][1].permute(1,2,0))

# %%
BATCH_SIZE = 50

train_dataloader = DataLoader(train_dataset, BATCH_SIZE, shuffle = True)
val_dataloader = DataLoader(val_dataset, BATCH_SIZE)

# %%
class EarlyStopping:

    def __init__(self, patience=5, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
        
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)

        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True

        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
class EfficientUNet_B0(nn.Module):
    def __init__(self):
        super().__init__()

        self.main = efficientunet.get_efficientunet_b0(out_channels=3, concat_input=True, pretrained=True)

    def forward(self, inpt):
        out = self.main(inpt)
        out = F.sigmoid(out)
        return out

# %%
torchinfo.summary(model, (1, 3, 192, 192))
# Out:
# ...
# Layer (type:depth-idx)                             Output Shape              Param #
# ...
# EfficientUNet_B0                                   [1, 3, 192, 192]          --
# ├─EfficientUnet: 1-1                               [1, 3, 192, 192]          --
# │    └─Encoder: 2-1                                [1, 1280, 6, 6]           --
# │    │    └─Conv2dSamePadding: 3-1                 [1, 32, 96, 96]           864
# │    │    └─BatchNorm2d: 3-2                       [1, 32, 96, 96]           64
# │    │    └─Swish: 3-3                             [1, 32, 96, 96]           --
# │    │    └─ModuleList: 3-4                        --                        3,594,460
# │    │    └─Conv2dSamePadding: 3-5                 [1, 1280, 6, 6]           409,600
# │    │    └─BatchNorm2d: 3-6                       [1, 1280, 6, 6]           2,560
# │    │    └─Swish: 3-7                             [1, 1280, 6, 6]           --
# ...

# %%
model = EfficientUNet_B0().to(device)

# %%
# run = wandb.init(
#     project = 'face_regen',
#     notes = 'efficientunet baseline',
#     tags = ['baseline', 'original']
# )

# wandb.config = {'epochs': 100, 'learning_rate': 0.001, 'batch_size': 50}

# %%
# EPOCHS = 100

# model = EfficientUNet_B0().to(device)
# optim = torch.optim.Adam(model.parameters(), lr = 1e-3)
# criterion = torch.nn.MSELoss()
# # early_stopping = EarlyStopping(patience=100, verbose=True, path = 'efficientunet_temp.pth')


# for epoch_num in range(EPOCHS):
#     train_loss = 0
#     i = 0

#     bar = tqdm(train_dataloader)
#     for img, mask in bar:
#         i+=1
#         optim.zero_grad()

#         img = img.to(device)
#         mask = mask.to(device)
#         predictions = model(mask)

#         batch_loss = criterion(predictions, img)

#         batch_loss.backward()
#         optim.step()

#         train_loss+= batch_loss.item()
#         bar.set_description_str("Training loss: {:.4f}".format(train_loss/i))

#     train_loss/=i

    
#     with torch.no_grad():
#         val_loss = 0
#         i = 0
#         bar = tqdm(val_dataloader)
#         for img, mask in bar:
#             i+=1
#             optim.zero_grad()

#             img = img.to(device)
#             mask = mask.to(device)
#             predictions = model(mask)

#             batch_loss = criterion(predictions, img)

#             val_loss+= batch_loss.item()
#             bar.set_description_str("Validation loss: {:.4f}".format(val_loss/i))

#         val_loss/=i


#     print("Epoch [{}/{}], Train Loss: {:.4f}".format(epoch_num+1, EPOCHS, train_loss))
#     print("Epoch [{}/{}], Val Loss: {:.4f}".format(epoch_num+1, EPOCHS, val_loss))


#     wandb.log({"train_loss": train_loss, "val_loss": val_loss})
#     torch.save(model.state_dict(), 'efficientunet_temp.pth')
#     # early_stopping(val_loss, model)

#     # if early_stopping.early_stop:
#     #     print("Early stopping")
#     #     print('-'*60)
#     #     break


# torch.save(model.state_dict(), 'efficientunet_trained_complete.pth')

# %%
model = EfficientUNet_B0().to(device)
with open('efficientunet_temp.pth', 'rb') as f:
    model.load_state_dict(torch.load(f, map_location={'cuda:1':'cuda:0'}))

# %%
i = random.randint(0, len(val_dataset))

img, mask = train_dataset[i]
unmasked = model(mask[None, ...].float().to(device))

fig, ax = plt.subplots(1, 3)
ax[0].imshow(img.cpu().permute(1, 2, 0))
ax[1].imshow(mask.cpu().permute(1, 2, 0))
ax[2].imshow(unmasked[0].detach().cpu().permute(1, 2, 0))

# %%
newsize = (64, 64)
new_resize = transforms.Resize(newsize)
img = new_resize(img)
mask = new_resize(mask)

# %%
fig, ax = plt.subplots(1, 2)
ax[0].imshow(img.cpu().permute(1, 2, 0))
ax[1].imshow(mask.cpu().permute(1, 2, 0))

# %%
unmasked = model(mask[None, ...].float().to(device))

# %%
fig, ax = plt.subplots(1, 2)
ax[0].imshow(img.cpu().permute(1, 2, 0))
ax[1].imshow(unmasked[0].detach().cpu().permute(1, 2, 0))
